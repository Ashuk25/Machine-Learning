# %%
import pandas as pd
import requests

# %% [markdown]
# Enter your API Key

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key={}&&language=en-US&page={}'.format('Your_API_Key','1'))

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3  19404  Dilwale Dulhania Le Jayenge
# 4    424             Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      97.119
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      82.607
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      63.884
# 3  Raj is a rich, carefree, happy-go-lucky second...   1995-10-19      22.713
# 4  The true story of how businessman Oskar Schind...   1993-12-15      46.255
#
#    vote_average  vote_count
# 0           8.7       18014
# 1           8.7       23861
# 2           8.6       10879
# 3           8.6        4137
# 4           8.6       14114

# %%
df = pd.DataFrame()

# %%
lst = []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key={}&&language=en-US&page={}'.format('Your_API_Key',i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    lst.append(temp_df)

# %%
df = pd.concat(lst, ignore_index=True)

# %%
df.shape
# Out:
# (17120, 7)

# %%
df.to_csv('movies.csv')
